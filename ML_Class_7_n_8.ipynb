# %% [markdown]
# <a href="https://colab.research.google.com/github/EJ-Ellie-John/NEDpython/blob/main/ML_Class_7_n_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
uploaded = files.upload()


from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
# Out:
#      <input type="file" id="files-903cc67e-78fc-4884-8a07-195a37e56a4f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-903cc67e-78fc-4884-8a07-195a37e56a4f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Social_Network_Ads.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.describe

# %%
df.isnull().sum()

# %%
from google.colab import files
uploaded = files.upload()

df=pd.read_csv('Social_Network_Ads_Experiment.csv')
df.head()

# %%
df.shape

# %%
df.describe

# %%
df.isnull().sum()

# %%
df.isnull().sum()
#df.fillna(df['Age'].mean(),inplace=True)
#df.isnull().sum()

# %% [markdown]
# Permanent change is done through INPLACE

# %%
df.fillna(df['Age'].mean(),inplace=True)
df.isnull().sum()

#df.fillna(df['EstimatedSalary'].mean(),inplace=True)
#df.isnull().sum()

# %% [markdown]
# You can run a loop with each column and filling with MEAN or MEDIAN

# %%
df['EstimatedSalary'] = df.fillna(df['EstimatedSalary'].mean(),inplace=True)
df.isnull().sum()

# %%
X=df.drop(columns=['Purchased'])
Y=df['Purchased']

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=45)

# %%
labelencoder = LabelEncoder()
X_train['Gender'] = labelencoder.fit_transform(X_train['Gender'])
X_test['Gender'] = labelencoder.transform(X_test['Gender'])
X_train
X_test
# Out:
#       User ID  Gender  Age  EstimatedSalary
# 255  15750056       0   52            90000
# 346  15646936       1   53            72000
# 228  15691808       0   40            72000
# 384  15806901       0   57            33000
# 269  15583137       1   40            61000
# ..        ...     ...  ...              ...
# 320  15774872       0   52           138000
# 73   15782530       0   33           113000
# 79   15655123       0   26            17000
# 390  15807837       1   48            33000
# 204  15660866       0   58           101000
#
# [80 rows x 4 columns]

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

X_train
X_test
# Out:
# array([[ 0.83697871, -0.97530483,  1.42135711,  0.60137626],
#        [-0.60233691,  1.02532046,  1.52023412,  0.07075015],
#        [ 0.02397196, -0.97530483,  0.23483291,  0.07075015],
#        [ 1.63040285, -0.97530483,  1.91574219, -1.07893976],
#        [-1.49282273,  1.02532046,  0.23483291, -0.25352136],
#        [-0.25123155, -0.97530483, -1.84158443, -1.4326905 ],
#        [-1.47317032, -0.97530483, -0.55618322,  0.48345935],
#        [ 1.08298277, -0.97530483, -0.25955217,  0.07075015],
#        [-0.22990422,  1.02532046, -1.24832233,  0.51293858],
#        [ 1.63911244, -0.97530483,  2.11349622, -1.19685668],
#        [-1.22433286,  1.02532046, -0.85281426,  0.15918783],
#        [-0.19958815,  1.02532046,  0.72921799,  0.27710475],
#        [ 0.06008047, -0.97530483, -1.34719935, -1.10841899],
#        [ 1.18981482,  1.02532046,  1.81686517, -0.28300059],
#        [ 0.06089002,  1.02532046,  0.1359559 , -0.81362671],
# ...
